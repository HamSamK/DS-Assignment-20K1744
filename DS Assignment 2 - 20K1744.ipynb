# %%
from matplotlib import pyplot as py
import seaborn as sns

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[0.97, 1.03, 0.99, 1.02, 0.97, 1.05]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 50 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("black")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[1.00, 1.00, 0.98, 1.02, 0.97, 0.99]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 100 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[0.97,1.22,1.00,1.03,0.96,0.98]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 200 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[1.11,1.22,1.03,1.00,1.00,1.05]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 300 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[1.05,1.00,0.98,1.00,0.96,1.05]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 400 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[0.98,1.02,0.97,0.98,0.95,0.93]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 500 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()

# %%
Sorts = ["Insertion", "Merge", "Quick I", "Quick II", "Quick III","Quick IV"]
Time_taken=[1.36,1.23,1.00,1.02,0.92,0.89]
py.figure(figsize=(15,4))
py.xlabel("Algorithms")
py.ylabel("""Time Taken (in s)""")
py.title("Compilation Times for 1000 Random Values")
py.bar(Sorts, Time_taken, color=['#7E2F8E','#00FF00','#4DBEEE','#A2142F', '#EDB120', '#D95319'])
ax.set_facecolor("#000000")
py.show()
